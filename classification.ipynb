# %%
# !python tools/train.py  --config 'configs/resnet/resnet18_flowers_bs128.py'  --work-dir 'output/resnet18_flowers_bs128'
# Out:
# /home/MUTOWORLD/anaconda3/envs/mmcls/lib/python3.7/site-packages/mmcv/cnn/bricks/transformer.py:33: UserWarning: Fail to import ``MultiScaleDeformableAttention`` from ``mmcv.ops.multi_scale_deform_attn``, You should install ``mmcv-full`` if you need this module.
#   warnings.warn('Fail to import ``MultiScaleDeformableAttention`` from '
# 2022-10-13 13:56:08,061 - mmcls - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.13 (default, Mar 29 2022, 02:18:16) [GCC 7.5.0]
# CUDA available: True
# GPU 0: Tesla P100-PCIE-16GB
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 11.6, V11.6.112
# GCC: gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-44)
# PyTorch: 1.7.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# ...
